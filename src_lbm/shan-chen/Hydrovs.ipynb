# %%
import yt
from matplotlib import rc_context
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import numpy as np
print(yt.__version__)

step = 1

plot_file_path = "./data_mixture/plt" + f"{step:05d}" # total 9 digits number for step info 
ds = yt.load(plot_file_path)
print(ds.field_list)
#profile_data = ds.all_data()[("boxlib", "struct_fact_rho_rho")].to_ndarray()
profile_data = ds.covering_grid(
    level=0, left_edge=ds.domain_left_edge, dims=ds.domain_dimensions
)
rho = profile_data["boxlib", "rhoA"] # density
phi = profile_data["boxlib", "rhoB"] # potential
ufx = profile_data["boxlib", "uAx"] # magnitude
print(rho)
# Out:
# yt : [INFO     ] 2025-04-13 06:00:01,292 Parameters: current_time              = 1.0
# yt : [INFO     ] 2025-04-13 06:00:01,292 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-04-13 06:00:01,293 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-04-13 06:00:01,293 Parameters: domain_right_edge         = [1. 1. 1.]
# 4.4.0
# ...
