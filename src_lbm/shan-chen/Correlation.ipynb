# %%
def format_params(number, precision=2, exponent_digits=2):
    # Format the number in scientific notation
    scientific = f"{number:.{precision}e}"
    # Split into base and exponent
    base, exponent = scientific.split("e")
    # Reformat the exponent with leading zeros
    exponent = int(exponent)  # Convert to integer
    formatted_exponent = f"e{'+' if exponent >= 0 else '-'}{abs(exponent):0{exponent_digits}d}"
    return f"{base}{formatted_exponent}"

#format_params(temperature, 0, 1)
'''
find ./data_mixture/ -type d -name "plt2000410"
 du -sh <folder dir>    #   check folder size
'''
# Out:
# '\nfind ./data_mixture/ -type d -name "plt2000410"\n du -sh <folder dir>    #   check folder size\n'

# %%
import yt
from matplotlib import rc_context
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import numpy as np
print(yt.__version__)

############    modify if needed    ############################
step1 = 410
step_SF = 400000 #3500400   #900400
temperature = 1e-5
alpha0 = 0.
cs2 = 1./3.
nx = 32#64
ny = 32#2
nz = 32#2
#######################################################

plot_file_dir_SF_mag = "./data_mixture/plt_SF_mag00" + f"{step_SF:07d}" # total 9 digits number for step info 
plot_file_dir_SF_real_imag = "./data_mixture/lbm_data_shshan_alpha0_" + f"{step_SF:07d}"
ds = yt.load(plot_file_dir_SF_mag)
print(ds.field_list)
#profile_data = ds.all_data()[("boxlib", "struct_fact_rho_rho")].to_ndarray()
profile_data = ds.covering_grid(
    level=0, left_edge=ds.domain_left_edge, dims=ds.domain_dimensions
)
S_rho_FHDeX = profile_data["boxlib", "struct_fact_rhoA_rhoA"] # magnitude
S_phi_FHDeX = profile_data["boxlib", "struct_fact_rhoB_rhoB"] # magnitude
S_ufx_FHDeX = profile_data["boxlib", "struct_fact_uAx_uAx"] # magnitude
S_ufy_FHDeX = profile_data["boxlib", "struct_fact_uAy_uAy"] # magnitude 
S_ufz_FHDeX = profile_data["boxlib", "struct_fact_uAz_uAz"] # magnitude

print((S_rho_FHDeX/(temperature/cs2)))

box = ds.domain_dimensions
nxh = box[0]//2
kx = 2*np.pi/box[0]*(np.linspace(0, nxh-1, nxh))

S_rho_array_kx = S_rho_FHDeX[nxh%box[0]:(2*nxh-1)%box[0]+1,0,0]/(temperature/cs2)
S_phi_array_kx = S_phi_FHDeX[nxh%box[0]:(2*nxh-1)%box[0]+1,0,0]/(temperature/cs2)
S_ufx_array_kx = S_ufx_FHDeX[nxh%box[0]:(2*nxh-1)%box[0]+1,0,0]/(temperature)
S_ufy_array_kx = S_ufy_FHDeX[nxh%box[0]:(2*nxh-1)%box[0]+1,0,0]/(temperature)
S_ufz_array_kx = S_ufz_FHDeX[nxh%box[0]:(2*nxh-1)%box[0]+1,0,0]/(temperature)

'''
S_rho_array_kx = S_rho_FHDeX[0:nxh,0,0]/(temperature/cs2)
S_phi_array_kx = S_phi_FHDeX[0:nxh,0,0]/(temperature/cs2)
S_ufx_array_kx = S_ufx_FHDeX[0:nxh,0,0]/(temperature/2.)
S_ufy_array_kx = S_ufy_FHDeX[0:nxh,0,0]/(temperature/2.)
S_ufz_array_kx = S_ufz_FHDeX[0:nxh,0,0]/(temperature/2.)
'''

plt.figure(1, figsize=(8, 6), dpi=100)  # Optional: Set the figure size
#fig, ax = plt.subplots()
plt.plot(kx, S_rho_array_kx, label="[ky,kz]=[0,0]", marker='o', linestyle='', color='b') 
plt.legend(title="Figure 1")

plt.xlabel("X-axis")  # X-axis label
plt.ylabel("Y-axis")  # Y-axis label
plt.title("S rho vs kx (alpha0={:.2f}), size=({:d},{:d},{:d})".format(alpha0,nx,ny,nz))  # Plot title
plt.ylim(0,1.2)
plt.grid(True)

plt.figure(2, figsize=(8, 6), dpi=100)  # Optional: Set the figure size
#fig, ax = plt.subplots()
plt.plot(kx, S_phi_array_kx, label="[ky,kz]=[0,0]", marker='o', linestyle='', color='b') 
plt.legend(title="Figure 1")

plt.xlabel("X-axis")  # X-axis label
plt.ylabel("Y-axis")  # Y-axis label
plt.title("S phi vs kx (alpha0={:.2f}), size=({:d},{:d},{:d})".format(alpha0,nx,ny,nz))  # Plot title
plt.ylim(0,1.2)
plt.grid(True)

plt.figure(3, figsize=(8, 6), dpi=100)  # Optional: Set the figure size
#fig, ax = plt.subplots()
plt.plot(kx, S_ufx_array_kx, label="[ky,kz]=[0,0]", marker='o', linestyle='', color='b') 
plt.legend(title="Figure 1")

plt.xlabel("X-axis")  # X-axis label
plt.ylabel("Y-axis")  # Y-axis label
plt.title("S ufx vs kx (alpha0={:.2f}), size=({:d},{:d},{:d})".format(alpha0,nx,ny,nz))  # Plot title
plt.ylim(0,1.6)
plt.grid(True)

plt.figure(4, figsize=(8, 6), dpi=100)  # Optional: Set the figure size
#fig, ax = plt.subplots()
plt.plot(kx, S_ufy_array_kx, label="[ky,kz]=[0,0]", marker='o', linestyle='', color='b') 
plt.legend(title="Figure 1")

plt.xlabel("X-axis")  # X-axis label
plt.ylabel("Y-axis")  # Y-axis label
plt.title("S ufy vs kx (alpha0={:.2f}), size=({:d},{:d},{:d})".format(alpha0,nx,ny,nz))  # Plot title
plt.ylim(0,1.6)
plt.grid(True)

plt.figure(5, figsize=(8, 6), dpi=100)  # Optional: Set the figure size
#fig, ax = plt.subplots()
plt.plot(kx, S_ufz_array_kx, label="[ky,kz]=[0,0]", marker='o', linestyle='', color='b') 
plt.legend(title="Figure 1")

plt.xlabel("X-axis")  # X-axis label
plt.ylabel("Y-axis")  # Y-axis label
plt.title("S ufz vs kx (alpha0={:.2f}), size=({:d},{:d},{:d})".format(alpha0,nx,ny,nz))  # Plot title
plt.ylim(0,1.6)
plt.grid(True)

# Show the plot
plt.show()
#plt.savefig('my_plot.png', dpi=300)
# Out:
# 4.4.0
# yt : [INFO     ] 2025-04-24 08:35:09,844 Parameters: current_time              = 400000.0
# yt : [INFO     ] 2025-04-24 08:35:09,845 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2025-04-24 08:35:09,845 Parameters: domain_left_edge          = [-8.5 -8.5 -8.5]
# yt : [INFO     ] 2025-04-24 08:35:09,846 Parameters: domain_right_edge         = [7.5 7.5 7.5]
# [('boxlib', 'struct_fact_rhoA_rhoA'), ('boxlib', 'struct_fact_rhoB_rhoB'), ('boxlib', 'struct_fact_uAx_uAx'), ('boxlib', 'struct_fact_uAy_uAy'), ('boxlib', 'struct_fact_uAz_uAz')]
# [[[0.96012544 0.97581259 0.99577782 ... 1.0081176  0.99577782 0.97581259]
#   [0.98093408 0.99102206 0.9998168  ... 1.00157846 1.00729658 0.99793481]
#   [0.98931358 0.99050329 0.98761299 ... 1.02968312 0.96968277 0.99615068]
#   ...
#   [0.9596833  0.96998221 0.95469492 ... 0.99267014 0.97556634 0.98661241]
#   [0.98931358 0.99615068 0.96968277 ... 0.93538333 0.98761299 0.99050329]
#   [0.98093408 0.99793481 1.00729658 ... 0.96771195 0.9998168  0.99102206]]
#
#  [[0.99807575 1.05161054 0.96294957 ... 0.97824139 0.99312152 0.97628342]
#   [0.99627661 0.95924088 1.02849702 ... 0.9668972  1.00188395 0.9604799 ]
#   [1.05785136 0.96411303 0.96940047 ... 0.98441825 0.98559684 0.97597202]
#   ...
#   [0.98990296 0.98205849 0.98321407 ... 0.97998361 0.98188331 1.01453839]
#   [1.03530879 0.98489149 0.97798774 ... 0.98857167 0.980665   1.00054116]
#   [0.99440461 1.02089171 0.9683966  ... 0.96138511 0.98115572 1.00147051]]
#
#  [[1.01670392 0.95075654 0.96080143 ... 0.96036819 0.96704964 1.00047144]
#   [0.99121534 1.04690965 0.98691626 ... 0.98722997 1.0295251  1.03441365]
#   [1.0022791  1.01190479 1.04417374 ... 0.97213369 0.97177682 0.95871549]
#   ...
#   [0.99415816 0.95848433 0.96353486 ... 0.98366624 0.96036575 1.00025407]
#   [1.00675425 1.00794829 0.95570875 ... 0.99093698 0.941302   0.973593  ]
#   [0.96642299 1.014009   0.99479784 ... 0.96394104 0.97279694 0.99081998]]
#
#  ...
#
#  [[0.98043173 0.97118499 0.95869011 ... 0.99153272 1.00803995 1.05347878]
#   [1.00418959 1.01287588 0.97197435 ... 0.99709138 1.0158881  1.01158988]
#   [1.02501199 1.00601529 0.9893817  ... 0.96948077 0.9944131  1.0028449 ]
#   ...
#   [0.96031058 0.99383875 0.92961448 ... 0.96607962 0.92043914 0.96161199]
#   [1.00092482 0.9989716  0.9515544  ... 0.98463355 0.95398631 0.97289117]
#   [0.99610503 1.00958487 0.99509993 ... 0.98695996 1.01615257 0.95856816]]
#
#  [[1.01670392 1.00047144 0.96704964 ... 1.00183084 0.96080143 0.95075654]
#   [0.96642299 0.99081998 0.97279694 ... 0.98234839 0.99479784 1.014009  ]
#   [1.00675425 0.973593   0.941302   ... 0.9523735  0.95570875 1.00794829]
#   ...
#   [1.00718285 1.03479227 0.97909858 ... 0.92471725 0.97322885 0.96931026]
#   [1.0022791  0.95871549 0.97177682 ... 0.98348232 1.04417374 1.01190479]
#   [0.99121534 1.03441365 1.0295251  ... 1.01192826 0.98691626 1.04690965]]
#
#  [[0.99807575 0.97628342 0.99312152 ... 0.99909174 0.96294957 1.05161054]
#   [0.99440461 1.00147051 0.98115572 ... 1.01948895 0.9683966  1.02089171]
#   [1.03530879 1.00054116 0.980665   ... 0.96784503 0.97798774 0.98489149]
#   ...
#   [0.97371519 1.06028847 0.9979173  ... 0.97413404 0.94168253 0.97723928]
#   [1.05785136 0.97597202 0.98559684 ... 0.9627086  0.96940047 0.96411303]
#   [0.99627661 0.9604799  1.00188395 ... 0.96447563 1.02849702 0.95924088]]] dimensionless

# %%
##############################
nx = 64
ny = 2
nz = 2
temperature = 1e-5
alpha0 = 0.
##############################

plot_file_dir_S_rho = "./data_mixture/lbm_data_shshan_alpha0_" + "{:.2f}".format(alpha0) +\
          "_xi_" + "{:.1e}".format(temperature) \
            + "_size{:d}-{:d}-{:d}_continue/correlation_rho".format(nx, ny, nz)

ds = yt.load(plot_file_dir_S_rho)
box = ds.domain_dimensions
print(ds.field_list)
#profile_data_S_rho = ds.all_data()[("boxlib", "S_rho")].to_ndarray()
profile_data_S_rho = ds.covering_grid(
    level=0, left_edge=ds.domain_left_edge, dims=ds.domain_dimensions
)

S_rho_array = profile_data_S_rho["boxlib", "S_rho"]
#S_rho_array = profile_data_S_rho["boxlib", "struct_fact_rho_rho"]

#S_rho_array = profile_data_S_rho.reshape(box[0],box[1],box[2])
#print(S_rho_array.max())
nxh = box[0]//2
kx = 2*np.pi/box[0]*(np.linspace(0, nxh-1, nxh))
S_rho_array_kx = S_rho_array[nxh%box[0]:(2*nxh-1)%box[0]+1,0,0]/(temperature/cs2) # add 1 additional position
S_rho_array_kx_0_1 = S_rho_array[nxh%box[0]:(2*nxh-1)%box[0]+1,0,1]/(temperature/cs2) # add 1 additional position
S_rho_array_kx_1_0 = S_rho_array[nxh%box[0]:(2*nxh-1)%box[0]+1,1,0]/(temperature/cs2) # add 1 additional position
S_rho_array_kx_1_1 = S_rho_array[nxh%box[0]:(2*nxh-1)%box[0]+1,1,1]/(temperature/cs2) # add 1 additional position


# Plotting the data
plt.figure(figsize=(8, 6), dpi=100)  # Optional: Set the figure size
#fig, ax = plt.subplots()
plt.plot(kx, S_rho_array_kx, label="[ky,kz]=[0,0]", marker='o', linestyle='', color='b')  # Create a line plot
#plt.plot(kx, S_rho_array_kx_0_1, label='[ky,kz]=[0,1]', marker='o', linestyle='', color='r')  # Create a line plot
#plt.plot(kx, S_rho_array_kx_1_0, label='[ky,kz]=[1,0]', marker='o', linestyle='', color='k')  # Create a line plot
#plt.plot(kx, S_rho_array_kx_1_1, label='[ky,kz]=[1,1]', marker='o', linestyle='', color='g')  # Create a line plot
plt.legend(title="Figure 1")
#ax.set_ylim(0, 2)  # Set y-axis range from -2 to 2

# Add labels and title
plt.xlabel("X-axis")  # X-axis label
plt.ylabel("Y-axis")  # Y-axis label
plt.title("S rho vs kx (alpha0={:.2f}), size=({:d},{:d},{:d})".format(alpha0,nx,ny,nz))  # Plot title

# Add a legend
# Display the grid (optional)
plt.grid(True)
# Show the plot
plt.show()
plt.savefig('my_plot.png', dpi=300)
# Out:
# yt : [ERROR    ] 2025-02-21 15:08:33,529 None of the arguments provided to load() is a valid file
# yt : [ERROR    ] 2025-02-21 15:08:33,531 Please check that you have used a correct path
# ---------------------------------------------------------------------------
# YTOutputNotIdentified                     Traceback (most recent call last)
# <ipython-input-3-799c69842e51> in <module>
#      11             + "_size{:d}-{:d}-{:d}_continue/correlation_rho".format(nx, ny, nz)
#      12
# ---> 13 ds = yt.load(plot_file_dir_S_rho)
#      14 box = ds.domain_dimensions
#      15 print(ds.field_list)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/yt/convenience.py in load(*args, **kwargs)
#      74             mylog.error("None of the arguments provided to load() is a valid file")
#      75             mylog.error("Please check that you have used a correct path")
# ---> 76             raise YTOutputNotIdentified(args, kwargs)
#      77     for n, c in types_to_check.items():
#      78         if n is None: continue
#
# YTOutputNotIdentified: Supplied ('./data_mixture/lbm_data_shshan_alpha0_0.00_xi_1.0e-05_size64-2-2_continue/correlation_rho',) {}, but could not load!

# %%
##############         DENSITY         ################
nx = 32 #64
ny = 32 #2
nz = 32 #2
temperature = 1e-5
alpha0 = 0.
#######################################################
import numpy as np

#plot_file_rho_mean = "./data_mixture/rho_steps.txt"
#plot_file_phi_mean = "./data_mixture/phi_steps.txt" # 2 currently uptp 2500400

plot_file_hydrovs_root = ""
if temperature > 0:
    plot_file_hydrovs_root += "./data_mixture/lbm_data_shshan_alpha0_" + "{:.2f}".format(alpha0) +\
          "_xi_" + "{:.1e}".format(temperature) + "_size{:d}-{:d}-{:d}_continue/plt".format(nx,ny,nz)
else:
    plot_file_hydrovs_root += "./data_mixture/lbm_data_shshan_alpha0_" + "{:.2f}".format(alpha0) +\
          "_xi_" + "{:.1e}".format(temperature) + "_size{:d}-{:d}-{:d}/plt".format(nx,ny,nz)
folder_path = plot_file_hydrovs_root[:len(plot_file_hydrovs_root)-3]
plot_file_rho_mean = folder_path + "rho_steps.txt"
plot_file_phi_mean = folder_path + "phi_steps.txt"

rho_array = np.genfromtxt(plot_file_rho_mean, delimiter='\t', invalid_raise=False)
phi_array = np.genfromtxt(plot_file_phi_mean, delimiter='\t', invalid_raise=False)
step = np.arange(rho_array.shape[0])

step = np.arange(rho_array.shape[0])
plt.plot(step, rho_array, label="rho", color='r')
plt.plot(step, phi_array, label="phi", color='b')
plt.plot(step, rho_array + phi_array, label="rho_tot", color='k')
plt.legend(title="Figure density ~ steps")
plt.xlabel('Index')  # Label for x-axis
plt.ylabel('Y-values')  # Label for y-axis
plt.title('Plot of the Data')  # Title
plt.show()
# Out:
# /tmp/ipykernel_177747/2761356091.py:24: ConversionWarning: Some errors were detected !
#     Line #454 (got 2 columns instead of 1)
#   rho_array = np.genfromtxt(plot_file_rho_mean, delimiter='\t', invalid_raise=False)
# /tmp/ipykernel_177747/2761356091.py:25: ConversionWarning: Some errors were detected !
#     Line #454 (got 2 columns instead of 1)
#   phi_array = np.genfromtxt(plot_file_phi_mean, delimiter='\t', invalid_raise=False)

# %%
############    Generate mean density by given init steps & interval    ############################
step1 = 10000
step2 = 700000
plot_int = 5000 #10
temperature = 1e-5
alpha0 = 0.
cs2 = 1./3.
nx = 32
ny = 32
nz = 32
ncomp = 19  # nvel in LBM
###############################################################

Nframes = (step2 - step1)//plot_int + 1
density_ndarray = np.zeros((Nframes, 2, nx, ny, nz))

plot_file_hydrovs_root = ""
if temperature > 0:
    plot_file_hydrovs_root += "./data_mixture/lbm_data_shshan_alpha0_" + "{:.2f}".format(alpha0) +\
          "_xi_" + "{:.1e}".format(temperature) + "_size{:d}-{:d}-{:d}_continue/plt".format(nx,ny,nz)
else:
    plot_file_hydrovs_root += "./data_mixture/lbm_data_shshan_alpha0_" + "{:.2f}".format(alpha0) +\
          "_xi_" + "{:.1e}".format(temperature) + "_size{:d}-{:d}-{:d}/plt".format(nx,ny,nz)


# load in noise multifab of each frame into ndarray
for n in range(step1, step2+1, plot_int):
    plot_file_fnoise = plot_file_hydrovs_root + f"{n:07d}"
    ds0 = yt.load(plot_file_fnoise)
    hydrovs_data_frame = ds0.covering_grid(
    level=0, left_edge=ds0.domain_left_edge, dims=ds0.domain_dimensions)
    #density_ndarray[(n-step1)//plot_int, 0, :,:,:] = hydrovs_data_frame["boxlib", "rho"]
    #density_ndarray[(n-step1)//plot_int, 1, :,:,:] = hydrovs_data_frame["boxlib", "phi"]
    rho_array[(n-step1)//plot_int] = np.mean(hydrovs_data_frame["boxlib", "rho"])
    phi_array[(n-step1)//plot_int] = np.mean(hydrovs_data_frame["boxlib", "phi"])

# Open the file in append mode and save data
plot_file_rho = plot_file_hydrovs_root[:len(plot_file_hydrovs_root)-3] + "rho_steps.txt"
plot_file_phi = plot_file_hydrovs_root[:len(plot_file_hydrovs_root)-3] + "phi_steps.txt"
#print(plot_file_rho)

with open(plot_file_rho, "a") as f:
    np.savetxt(f, phi_array, delimiter="\t", fmt="%.6f")
    f.write("\t")
with open(plot_file_phi, "a") as f:
    np.savetxt(f, rho_array, delimiter="\t", fmt="%.6f")
    f.write("\t")
# Out:
# yt : [INFO     ] 2025-03-13 00:38:22,210 Parameters: current_time              = 10000.0
# yt : [INFO     ] 2025-03-13 00:38:22,211 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-13 00:38:22,211 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-13 00:38:22,212 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-13 00:38:22,359 Parameters: current_time              = 15000.0
# yt : [INFO     ] 2025-03-13 00:38:22,360 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-13 00:38:22,361 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-13 00:38:22,362 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-13 00:38:22,529 Parameters: current_time              = 20000.0
# yt : [INFO     ] 2025-03-13 00:38:22,530 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-13 00:38:22,531 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-13 00:38:22,532 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-13 00:38:22,694 Parameters: current_time              = 25000.0
# yt : [INFO     ] 2025-03-13 00:38:22,695 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-13 00:38:22,696 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-13 00:38:22,697 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-13 00:38:22,854 Parameters: current_time              = 30000.0
# yt : [INFO     ] 2025-03-13 00:38:22,854 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-13 00:38:22,855 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-13 00:38:22,856 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-13 00:38:23,022 Parameters: current_time              = 35000.0
# yt : [INFO     ] 2025-03-13 00:38:23,023 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-13 00:38:23,024 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-13 00:38:23,025 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-13 00:38:23,179 Parameters: current_time              = 40000.0
# yt : [INFO     ] 2025-03-13 00:38:23,180 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-13 00:38:23,181 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-13 00:38:23,182 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-13 00:38:23,350 Parameters: current_time              = 45000.0
# yt : [INFO     ] 2025-03-13 00:38:23,351 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-13 00:38:23,352 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-13 00:38:23,353 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-13 00:38:23,512 Parameters: current_time              = 50000.0
# yt : [INFO     ] 2025-03-13 00:38:23,513 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-13 00:38:23,513 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-13 00:38:23,514 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-13 00:38:23,675 Parameters: current_time              = 55000.0
# yt : [INFO     ] 2025-03-13 00:38:23,676 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-13 00:38:23,677 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-13 00:38:23,678 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-13 00:38:23,830 Parameters: current_time              = 60000.0
# yt : [INFO     ] 2025-03-13 00:38:23,832 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-13 00:38:23,833 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-13 00:38:23,833 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-13 00:38:24,168 Parameters: current_time              = 65000.0
# yt : [INFO     ] 2025-03-13 00:38:24,168 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-13 00:38:24,170 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-13 00:38:24,172 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-13 00:38:24,326 Parameters: current_time              = 70000.0
# yt : [INFO     ] 2025-03-13 00:38:24,327 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-13 00:38:24,327 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-13 00:38:24,329 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-13 00:38:24,489 Parameters: current_time              = 75000.0
# yt : [INFO     ] 2025-03-13 00:38:24,490 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-13 00:38:24,490 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-13 00:38:24,491 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-13 00:38:24,667 Parameters: current_time              = 80000.0
# yt : [INFO     ] 2025-03-13 00:38:24,668 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-13 00:38:24,669 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-13 00:38:24,669 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-13 00:38:24,832 Parameters: current_time              = 85000.0
# yt : [INFO     ] 2025-03-13 00:38:24,833 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-13 00:38:24,834 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-13 00:38:24,835 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-13 00:38:24,985 Parameters: current_time              = 90000.0
# yt : [INFO     ] 2025-03-13 00:38:24,986 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-13 00:38:24,987 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-13 00:38:24,988 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-13 00:38:25,145 Parameters: current_time              = 95000.0
# yt : [INFO     ] 2025-03-13 00:38:25,145 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-13 00:38:25,146 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-13 00:38:25,147 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-13 00:38:25,294 Parameters: current_time              = 100000.0
# yt : [INFO     ] 2025-03-13 00:38:25,295 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-13 00:38:25,296 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-13 00:38:25,297 Parameters: domain_right_edge         = [1. 1. 1.]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 36
#      34 for n in range(step1, step2+1, plot_int):
#      35     plot_file_fnoise = plot_file_hydrovs_root + f"{n:07d}"
# ---> 36     ds0 = yt.load(plot_file_fnoise)
#      37     hydrovs_data_frame = ds0.covering_grid(
#      38     level=0, left_edge=ds0.domain_left_edge, dims=ds0.domain_dimensions)
#      39     #density_ndarray[(n-step1)//plot_int, 0, :,:,:] = hydrovs_data_frame["boxlib", "rho"]
#      40     #density_ndarray[(n-step1)//plot_int, 1, :,:,:] = hydrovs_data_frame["boxlib", "phi"]
#
# File ~/anaconda3/lib/python3.12/site-packages/yt/_maintenance/deprecation.py:68, in future_positional_only.<locals>.outer.<locals>.inner(*args, **kwargs)
#      59     value = kwargs[name]
#      60     issue_deprecation_warning(
#      61         f"Using the {name!r} argument as keyword (on position {no}) "
#      62         "is deprecated. "
#    (...)
#      66         **depr_kwargs,
#      67     )
# ---> 68 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.12/site-packages/yt/loaders.py:111, in load(fn, hint, *args, **kwargs)
#     108 # This will raise FileNotFoundError if the path isn't matched
#     109 # either in the current dir or yt.config.ytcfg['data_dir_directory']
#     110 if not fn.startswith("http"):
# --> 111     fn = str(lookup_on_disk_data(fn))
#     113 external_frontends = entry_points(group="yt.frontends")
#     115 # Ensure that external frontends are loaded
#
# File ~/anaconda3/lib/python3.12/site-packages/yt/sample_data/api.py:187, in lookup_on_disk_data(fn)
#     185         return alt_path
#     186     err_msg += f"\n(Also tried '{alt_path}')."
# --> 187 raise FileNotFoundError(err_msg)
#
# FileNotFoundError: No such file or directory: './data_mixture/lbm_data_shshan_alpha0_0.00_xi_1.0e-05_size32-32-32_continue/plt0105000'.

# %%
############    Generate mean density by looping over folder    ############################
import os
import re

temperature = 1e-5
alpha0 = 0.
cs2 = 1./3.
nx = 32
ny = 32
nz = 32
ncomp = 19  # nvel in LBM
###############################################################

plot_file_hydrovs_root = ""
if temperature > 0:
    plot_file_hydrovs_root += "./data_mixture/lbm_data_shshan_alpha0_" + "{:.2f}".format(alpha0) +\
          "_xi_" + "{:.1e}".format(temperature) + "_size{:d}-{:d}-{:d}_continue/plt".format(nx,ny,nz)
else:
    plot_file_hydrovs_root += "./data_mixture/lbm_data_shshan_alpha0_" + "{:.2f}".format(alpha0) +\
          "_xi_" + "{:.1e}".format(temperature) + "_size{:d}-{:d}-{:d}/plt".format(nx,ny,nz)



# Specify the folder path
folder_path = plot_file_hydrovs_root[:len(plot_file_hydrovs_root)-3]
rho_array = []
phi_array = []
pattern = r"^plt\d+$"

# Loop through all files in the folder
for filename in sorted(os.listdir(folder_path)):  # Ensure order
    file_path = os.path.join(folder_path, filename)
    #print(f"Opening: {file_path}")  
    if re.match(pattern, filename):
        file_path = os.path.join(folder_path, filename)
        ds0 = yt.load(file_path)
        hydrovs_data_frame = ds0.covering_grid(
        level=0, left_edge=ds0.domain_left_edge, dims=ds0.domain_dimensions)    
        rho_array.append(np.mean(hydrovs_data_frame["boxlib", "rho"]))
        phi_array.append(np.mean(hydrovs_data_frame["boxlib", "phi"]))
    
plot_file_rho = folder_path + "rho_steps.txt"
plot_file_phi = folder_path + "phi_steps.txt"
with open(plot_file_rho, "w") as f: # overwrite mode
    np.savetxt(f, phi_array, delimiter="\t", fmt="%.6f")
    f.write("\t")
with open(plot_file_phi, "w") as f:
    np.savetxt(f, rho_array, delimiter="\t", fmt="%.6f")
    f.write("\t")
# Out:
# yt : [INFO     ] 2025-03-17 14:46:20,104 Parameters: current_time              = 2000.0
# yt : [INFO     ] 2025-03-17 14:46:20,106 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:20,107 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:20,108 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:21,004 Parameters: current_time              = 4000.0
# yt : [INFO     ] 2025-03-17 14:46:21,005 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:21,006 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:21,007 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:21,281 Parameters: current_time              = 6000.0
# yt : [INFO     ] 2025-03-17 14:46:21,282 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:21,282 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:21,283 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:21,492 Parameters: current_time              = 8000.0
# yt : [INFO     ] 2025-03-17 14:46:21,493 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:21,494 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:21,494 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:21,706 Parameters: current_time              = 10000.0
# yt : [INFO     ] 2025-03-17 14:46:21,707 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:21,708 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:21,709 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:21,960 Parameters: current_time              = 12000.0
# yt : [INFO     ] 2025-03-17 14:46:21,961 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:21,961 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:21,962 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:22,221 Parameters: current_time              = 14000.0
# yt : [INFO     ] 2025-03-17 14:46:22,222 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:22,224 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:22,225 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:22,478 Parameters: current_time              = 16000.0
# yt : [INFO     ] 2025-03-17 14:46:22,479 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:22,480 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:22,481 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:22,713 Parameters: current_time              = 18000.0
# yt : [INFO     ] 2025-03-17 14:46:22,714 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:22,715 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:22,716 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:22,939 Parameters: current_time              = 20000.0
# yt : [INFO     ] 2025-03-17 14:46:22,939 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:22,940 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:22,941 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:23,221 Parameters: current_time              = 22000.0
# yt : [INFO     ] 2025-03-17 14:46:23,222 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:23,223 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:23,224 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:23,443 Parameters: current_time              = 24000.0
# yt : [INFO     ] 2025-03-17 14:46:23,444 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:23,445 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:23,446 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:23,677 Parameters: current_time              = 26000.0
# yt : [INFO     ] 2025-03-17 14:46:23,678 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:23,679 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:23,680 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:23,903 Parameters: current_time              = 28000.0
# yt : [INFO     ] 2025-03-17 14:46:23,904 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:23,904 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:23,905 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:24,138 Parameters: current_time              = 30000.0
# yt : [INFO     ] 2025-03-17 14:46:24,139 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:24,140 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:24,141 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:24,565 Parameters: current_time              = 32000.0
# yt : [INFO     ] 2025-03-17 14:46:24,566 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:24,567 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:24,568 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:24,795 Parameters: current_time              = 34000.0
# yt : [INFO     ] 2025-03-17 14:46:24,795 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:24,796 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:24,796 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:25,032 Parameters: current_time              = 36000.0
# yt : [INFO     ] 2025-03-17 14:46:25,033 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:25,034 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:25,035 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:25,245 Parameters: current_time              = 38000.0
# yt : [INFO     ] 2025-03-17 14:46:25,246 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:25,247 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:25,247 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:25,419 Parameters: current_time              = 40000.0
# yt : [INFO     ] 2025-03-17 14:46:25,419 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:25,420 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:25,420 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:25,590 Parameters: current_time              = 42000.0
# yt : [INFO     ] 2025-03-17 14:46:25,591 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:25,591 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:25,592 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:25,767 Parameters: current_time              = 44000.0
# yt : [INFO     ] 2025-03-17 14:46:25,768 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:25,770 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:25,772 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:25,959 Parameters: current_time              = 46000.0
# yt : [INFO     ] 2025-03-17 14:46:25,959 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:25,960 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:25,960 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:26,165 Parameters: current_time              = 48000.0
# yt : [INFO     ] 2025-03-17 14:46:26,166 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:26,167 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:26,168 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:26,389 Parameters: current_time              = 50000.0
# yt : [INFO     ] 2025-03-17 14:46:26,390 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:26,391 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:26,392 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:26,584 Parameters: current_time              = 52000.0
# yt : [INFO     ] 2025-03-17 14:46:26,585 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:26,585 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:26,586 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:26,797 Parameters: current_time              = 54000.0
# yt : [INFO     ] 2025-03-17 14:46:26,798 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:26,799 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:26,800 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:27,016 Parameters: current_time              = 56000.0
# yt : [INFO     ] 2025-03-17 14:46:27,018 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:27,019 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:27,020 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:27,256 Parameters: current_time              = 58000.0
# yt : [INFO     ] 2025-03-17 14:46:27,256 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:27,257 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:27,258 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:27,465 Parameters: current_time              = 60000.0
# yt : [INFO     ] 2025-03-17 14:46:27,465 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:27,466 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:27,467 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:27,672 Parameters: current_time              = 62000.0
# yt : [INFO     ] 2025-03-17 14:46:27,673 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:27,673 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:27,674 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:27,933 Parameters: current_time              = 64000.0
# yt : [INFO     ] 2025-03-17 14:46:27,934 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:27,935 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:27,935 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:28,370 Parameters: current_time              = 66000.0
# yt : [INFO     ] 2025-03-17 14:46:28,371 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:28,372 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:28,373 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:28,585 Parameters: current_time              = 68000.0
# yt : [INFO     ] 2025-03-17 14:46:28,586 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:28,587 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:28,588 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:28,815 Parameters: current_time              = 70000.0
# yt : [INFO     ] 2025-03-17 14:46:28,816 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:28,817 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:28,819 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:29,004 Parameters: current_time              = 72000.0
# yt : [INFO     ] 2025-03-17 14:46:29,005 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:29,005 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:29,006 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:29,263 Parameters: current_time              = 74000.0
# yt : [INFO     ] 2025-03-17 14:46:29,263 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:29,264 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:29,265 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:29,478 Parameters: current_time              = 76000.0
# yt : [INFO     ] 2025-03-17 14:46:29,479 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:29,479 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:29,480 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:29,695 Parameters: current_time              = 78000.0
# yt : [INFO     ] 2025-03-17 14:46:29,696 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:29,696 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:29,697 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:29,889 Parameters: current_time              = 80000.0
# yt : [INFO     ] 2025-03-17 14:46:29,890 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:29,891 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:29,893 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:30,142 Parameters: current_time              = 82000.0
# yt : [INFO     ] 2025-03-17 14:46:30,143 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:30,144 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:30,146 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:30,318 Parameters: current_time              = 84000.0
# yt : [INFO     ] 2025-03-17 14:46:30,320 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:30,321 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:30,321 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:30,528 Parameters: current_time              = 86000.0
# yt : [INFO     ] 2025-03-17 14:46:30,529 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:30,530 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:30,531 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:30,753 Parameters: current_time              = 88000.0
# yt : [INFO     ] 2025-03-17 14:46:30,754 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:30,755 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:30,756 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:30,943 Parameters: current_time              = 90000.0
# yt : [INFO     ] 2025-03-17 14:46:30,943 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:30,944 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:30,945 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:31,172 Parameters: current_time              = 92000.0
# yt : [INFO     ] 2025-03-17 14:46:31,173 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:31,174 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:31,175 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:31,392 Parameters: current_time              = 94000.0
# yt : [INFO     ] 2025-03-17 14:46:31,393 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:31,393 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:31,394 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:31,603 Parameters: current_time              = 96000.0
# yt : [INFO     ] 2025-03-17 14:46:31,604 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:31,605 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:31,605 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:31,828 Parameters: current_time              = 98000.0
# yt : [INFO     ] 2025-03-17 14:46:31,829 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:31,830 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:31,830 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:32,070 Parameters: current_time              = 100000.0
# yt : [INFO     ] 2025-03-17 14:46:32,071 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:32,072 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:32,073 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:32,339 Parameters: current_time              = 102000.0
# yt : [INFO     ] 2025-03-17 14:46:32,341 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:32,342 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:32,343 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:32,892 Parameters: current_time              = 104000.0
# yt : [INFO     ] 2025-03-17 14:46:32,893 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:32,894 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:32,896 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:33,140 Parameters: current_time              = 106000.0
# yt : [INFO     ] 2025-03-17 14:46:33,141 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:33,142 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:33,143 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:33,356 Parameters: current_time              = 108000.0
# yt : [INFO     ] 2025-03-17 14:46:33,357 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:33,358 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:33,358 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:33,590 Parameters: current_time              = 110000.0
# yt : [INFO     ] 2025-03-17 14:46:33,591 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:33,592 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:33,594 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:33,828 Parameters: current_time              = 112000.0
# yt : [INFO     ] 2025-03-17 14:46:33,829 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:33,830 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:33,831 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:34,055 Parameters: current_time              = 114000.0
# yt : [INFO     ] 2025-03-17 14:46:34,057 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:34,058 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:34,059 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:34,277 Parameters: current_time              = 116000.0
# yt : [INFO     ] 2025-03-17 14:46:34,278 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:34,279 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:34,281 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:34,509 Parameters: current_time              = 118000.0
# yt : [INFO     ] 2025-03-17 14:46:34,510 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:34,511 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:34,511 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:34,731 Parameters: current_time              = 120000.0
# yt : [INFO     ] 2025-03-17 14:46:34,732 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:34,734 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:34,735 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:34,961 Parameters: current_time              = 122000.0
# yt : [INFO     ] 2025-03-17 14:46:34,962 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:34,962 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:34,963 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:35,205 Parameters: current_time              = 124000.0
# yt : [INFO     ] 2025-03-17 14:46:35,206 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:35,207 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:35,208 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:35,458 Parameters: current_time              = 126000.0
# yt : [INFO     ] 2025-03-17 14:46:35,458 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:35,459 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:35,460 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:35,682 Parameters: current_time              = 128000.0
# yt : [INFO     ] 2025-03-17 14:46:35,683 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:35,683 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:35,684 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:35,874 Parameters: current_time              = 130000.0
# yt : [INFO     ] 2025-03-17 14:46:35,874 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:35,875 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:35,876 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:36,114 Parameters: current_time              = 132000.0
# yt : [INFO     ] 2025-03-17 14:46:36,116 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:36,116 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:36,117 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:36,335 Parameters: current_time              = 134000.0
# yt : [INFO     ] 2025-03-17 14:46:36,335 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:36,336 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:36,337 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:36,559 Parameters: current_time              = 136000.0
# yt : [INFO     ] 2025-03-17 14:46:36,559 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:36,560 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:36,561 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:36,865 Parameters: current_time              = 138000.0
# yt : [INFO     ] 2025-03-17 14:46:36,866 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:36,866 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:36,868 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:37,161 Parameters: current_time              = 140000.0
# yt : [INFO     ] 2025-03-17 14:46:37,162 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:37,163 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:37,164 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:37,825 Parameters: current_time              = 142000.0
# yt : [INFO     ] 2025-03-17 14:46:37,826 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:37,827 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:37,828 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:38,041 Parameters: current_time              = 144000.0
# yt : [INFO     ] 2025-03-17 14:46:38,043 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:38,044 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:38,045 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:38,287 Parameters: current_time              = 146000.0
# yt : [INFO     ] 2025-03-17 14:46:38,288 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:38,289 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:38,290 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:38,484 Parameters: current_time              = 148000.0
# yt : [INFO     ] 2025-03-17 14:46:38,485 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:38,486 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:38,487 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:38,720 Parameters: current_time              = 150000.0
# yt : [INFO     ] 2025-03-17 14:46:38,721 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:38,722 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:38,724 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:38,923 Parameters: current_time              = 152000.0
# yt : [INFO     ] 2025-03-17 14:46:38,924 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:38,924 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:38,925 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:39,151 Parameters: current_time              = 154000.0
# yt : [INFO     ] 2025-03-17 14:46:39,152 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:39,153 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:39,154 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:39,312 Parameters: current_time              = 156000.0
# yt : [INFO     ] 2025-03-17 14:46:39,313 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:39,314 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:39,315 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:39,511 Parameters: current_time              = 158000.0
# yt : [INFO     ] 2025-03-17 14:46:39,512 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:39,513 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:39,514 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:39,675 Parameters: current_time              = 160000.0
# yt : [INFO     ] 2025-03-17 14:46:39,675 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:39,676 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:39,677 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:39,887 Parameters: current_time              = 162000.0
# yt : [INFO     ] 2025-03-17 14:46:39,888 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:39,889 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:39,890 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:40,119 Parameters: current_time              = 164000.0
# yt : [INFO     ] 2025-03-17 14:46:40,120 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:40,121 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:40,122 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:40,318 Parameters: current_time              = 166000.0
# yt : [INFO     ] 2025-03-17 14:46:40,319 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:40,320 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:40,321 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:40,515 Parameters: current_time              = 168000.0
# yt : [INFO     ] 2025-03-17 14:46:40,516 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:40,517 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:40,518 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:40,673 Parameters: current_time              = 170000.0
# yt : [INFO     ] 2025-03-17 14:46:40,673 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:40,675 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:40,675 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:40,835 Parameters: current_time              = 172000.0
# yt : [INFO     ] 2025-03-17 14:46:40,836 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:40,837 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:40,838 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:41,287 Parameters: current_time              = 174000.0
# yt : [INFO     ] 2025-03-17 14:46:41,288 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:41,288 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:41,289 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:41,497 Parameters: current_time              = 176000.0
# yt : [INFO     ] 2025-03-17 14:46:41,498 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:41,499 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:41,499 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:41,682 Parameters: current_time              = 178000.0
# yt : [INFO     ] 2025-03-17 14:46:41,683 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:41,684 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:41,685 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:41,928 Parameters: current_time              = 180000.0
# yt : [INFO     ] 2025-03-17 14:46:41,929 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:41,929 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:41,930 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:42,155 Parameters: current_time              = 182000.0
# yt : [INFO     ] 2025-03-17 14:46:42,156 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:42,158 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:42,159 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:42,353 Parameters: current_time              = 184000.0
# yt : [INFO     ] 2025-03-17 14:46:42,354 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:42,354 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:42,356 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:42,573 Parameters: current_time              = 186000.0
# yt : [INFO     ] 2025-03-17 14:46:42,574 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:42,574 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:42,575 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:42,779 Parameters: current_time              = 188000.0
# yt : [INFO     ] 2025-03-17 14:46:42,780 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:42,781 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:42,782 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:42,973 Parameters: current_time              = 190000.0
# yt : [INFO     ] 2025-03-17 14:46:42,974 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:42,974 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:42,975 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:43,177 Parameters: current_time              = 192000.0
# yt : [INFO     ] 2025-03-17 14:46:43,178 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:43,179 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:43,180 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:43,340 Parameters: current_time              = 194000.0
# yt : [INFO     ] 2025-03-17 14:46:43,341 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:43,342 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:43,342 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:43,526 Parameters: current_time              = 196000.0
# yt : [INFO     ] 2025-03-17 14:46:43,526 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:43,527 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:43,528 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:43,756 Parameters: current_time              = 198000.0
# yt : [INFO     ] 2025-03-17 14:46:43,757 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:43,758 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:43,759 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:43,922 Parameters: current_time              = 200000.0
# yt : [INFO     ] 2025-03-17 14:46:43,923 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:43,924 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:43,925 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:44,130 Parameters: current_time              = 202000.0
# yt : [INFO     ] 2025-03-17 14:46:44,131 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:44,131 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:44,132 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:44,317 Parameters: current_time              = 204000.0
# yt : [INFO     ] 2025-03-17 14:46:44,318 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:44,319 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:44,320 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:44,505 Parameters: current_time              = 206000.0
# yt : [INFO     ] 2025-03-17 14:46:44,505 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:44,506 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:44,507 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:44,977 Parameters: current_time              = 208000.0
# yt : [INFO     ] 2025-03-17 14:46:44,978 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:44,979 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:44,980 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:45,193 Parameters: current_time              = 210000.0
# yt : [INFO     ] 2025-03-17 14:46:45,194 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:45,194 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:45,195 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:45,428 Parameters: current_time              = 212000.0
# yt : [INFO     ] 2025-03-17 14:46:45,429 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:45,430 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:45,430 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:45,634 Parameters: current_time              = 214000.0
# yt : [INFO     ] 2025-03-17 14:46:45,635 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:45,636 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:45,637 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:45,865 Parameters: current_time              = 216000.0
# yt : [INFO     ] 2025-03-17 14:46:45,865 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:45,866 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:45,867 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:46,081 Parameters: current_time              = 218000.0
# yt : [INFO     ] 2025-03-17 14:46:46,082 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:46,083 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:46,084 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:46,263 Parameters: current_time              = 220000.0
# yt : [INFO     ] 2025-03-17 14:46:46,263 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:46,264 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:46,265 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:46,501 Parameters: current_time              = 222000.0
# yt : [INFO     ] 2025-03-17 14:46:46,502 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:46,504 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:46,505 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:46,693 Parameters: current_time              = 224000.0
# yt : [INFO     ] 2025-03-17 14:46:46,694 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:46,695 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:46,696 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:46,910 Parameters: current_time              = 226000.0
# yt : [INFO     ] 2025-03-17 14:46:46,911 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:46,912 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:46,912 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:47,137 Parameters: current_time              = 228000.0
# yt : [INFO     ] 2025-03-17 14:46:47,137 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:47,138 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:47,138 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:47,297 Parameters: current_time              = 230000.0
# yt : [INFO     ] 2025-03-17 14:46:47,298 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:47,299 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:47,300 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:47,466 Parameters: current_time              = 232000.0
# yt : [INFO     ] 2025-03-17 14:46:47,467 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:47,468 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:47,469 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:47,651 Parameters: current_time              = 234000.0
# yt : [INFO     ] 2025-03-17 14:46:47,652 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:47,652 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:47,653 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:47,839 Parameters: current_time              = 236000.0
# yt : [INFO     ] 2025-03-17 14:46:47,839 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:47,840 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:47,841 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:48,091 Parameters: current_time              = 238000.0
# yt : [INFO     ] 2025-03-17 14:46:48,092 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:48,093 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:48,094 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:48,251 Parameters: current_time              = 240000.0
# yt : [INFO     ] 2025-03-17 14:46:48,252 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:48,253 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:48,253 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:48,437 Parameters: current_time              = 242000.0
# yt : [INFO     ] 2025-03-17 14:46:48,438 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:48,438 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:48,438 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:48,905 Parameters: current_time              = 244000.0
# yt : [INFO     ] 2025-03-17 14:46:48,906 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:48,907 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:48,907 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:49,153 Parameters: current_time              = 246000.0
# yt : [INFO     ] 2025-03-17 14:46:49,153 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:49,154 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:49,155 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:49,381 Parameters: current_time              = 248000.0
# yt : [INFO     ] 2025-03-17 14:46:49,382 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:49,382 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:49,383 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:49,621 Parameters: current_time              = 250000.0
# yt : [INFO     ] 2025-03-17 14:46:49,622 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:49,624 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:49,624 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:49,799 Parameters: current_time              = 252000.0
# yt : [INFO     ] 2025-03-17 14:46:49,800 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:49,800 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:49,801 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:50,022 Parameters: current_time              = 254000.0
# yt : [INFO     ] 2025-03-17 14:46:50,023 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:50,024 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:50,025 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:50,263 Parameters: current_time              = 256000.0
# yt : [INFO     ] 2025-03-17 14:46:50,263 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:50,264 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:50,265 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:50,444 Parameters: current_time              = 258000.0
# yt : [INFO     ] 2025-03-17 14:46:50,444 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:50,445 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:50,446 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:50,634 Parameters: current_time              = 260000.0
# yt : [INFO     ] 2025-03-17 14:46:50,635 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:50,636 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:50,637 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:50,788 Parameters: current_time              = 262000.0
# yt : [INFO     ] 2025-03-17 14:46:50,788 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:46:50,789 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:46:50,790 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:46:50,957 Parameters: current_time              = 264000.0
# ...
# yt : [INFO     ] 2025-03-17 14:47:50,220 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:47:50,221 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:47:50,426 Parameters: current_time              = 818000.0
# yt : [INFO     ] 2025-03-17 14:47:50,427 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:47:50,428 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:47:50,429 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:47:50,635 Parameters: current_time              = 820000.0
# yt : [INFO     ] 2025-03-17 14:47:50,636 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:47:50,637 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:47:50,638 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:47:50,792 Parameters: current_time              = 822000.0
# yt : [INFO     ] 2025-03-17 14:47:50,792 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:47:50,793 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:47:50,794 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:47:50,941 Parameters: current_time              = 824000.0
# yt : [INFO     ] 2025-03-17 14:47:50,942 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:47:50,943 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:47:50,943 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:47:51,158 Parameters: current_time              = 826000.0
# yt : [INFO     ] 2025-03-17 14:47:51,159 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:47:51,159 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:47:51,160 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:47:51,348 Parameters: current_time              = 828000.0
# yt : [INFO     ] 2025-03-17 14:47:51,348 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:47:51,349 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:47:51,350 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:47:51,513 Parameters: current_time              = 830000.0
# yt : [INFO     ] 2025-03-17 14:47:51,514 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:47:51,514 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:47:51,515 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:47:51,702 Parameters: current_time              = 832000.0
# yt : [INFO     ] 2025-03-17 14:47:51,703 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:47:51,704 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:47:51,705 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:47:51,890 Parameters: current_time              = 834000.0
# yt : [INFO     ] 2025-03-17 14:47:51,891 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:47:51,891 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:47:51,892 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:47:52,123 Parameters: current_time              = 836000.0
# yt : [INFO     ] 2025-03-17 14:47:52,125 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:47:52,126 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:47:52,127 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:47:52,586 Parameters: current_time              = 838000.0
# yt : [INFO     ] 2025-03-17 14:47:52,587 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:47:52,587 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:47:52,588 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:47:52,742 Parameters: current_time              = 840000.0
# yt : [INFO     ] 2025-03-17 14:47:52,742 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:47:52,743 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:47:52,744 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:47:52,893 Parameters: current_time              = 842000.0
# yt : [INFO     ] 2025-03-17 14:47:52,894 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:47:52,895 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:47:52,896 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:47:53,081 Parameters: current_time              = 844000.0
# yt : [INFO     ] 2025-03-17 14:47:53,082 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:47:53,083 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:47:53,084 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:47:53,227 Parameters: current_time              = 846000.0
# yt : [INFO     ] 2025-03-17 14:47:53,228 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:47:53,229 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:47:53,230 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:47:53,388 Parameters: current_time              = 848000.0
# yt : [INFO     ] 2025-03-17 14:47:53,389 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:47:53,390 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:47:53,391 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:47:53,546 Parameters: current_time              = 850000.0
# yt : [INFO     ] 2025-03-17 14:47:53,547 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:47:53,547 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:47:53,548 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:47:53,699 Parameters: current_time              = 852000.0
# yt : [INFO     ] 2025-03-17 14:47:53,700 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:47:53,701 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:47:53,702 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:47:53,838 Parameters: current_time              = 854000.0
# yt : [INFO     ] 2025-03-17 14:47:53,838 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:47:53,839 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:47:53,840 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:47:54,051 Parameters: current_time              = 856000.0
# yt : [INFO     ] 2025-03-17 14:47:54,052 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:47:54,053 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:47:54,055 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:47:54,254 Parameters: current_time              = 858000.0
# yt : [INFO     ] 2025-03-17 14:47:54,254 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:47:54,255 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:47:54,256 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:47:54,445 Parameters: current_time              = 860000.0
# yt : [INFO     ] 2025-03-17 14:47:54,446 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:47:54,447 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:47:54,448 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:47:54,659 Parameters: current_time              = 862000.0
# yt : [INFO     ] 2025-03-17 14:47:54,659 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:47:54,660 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:47:54,661 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:47:54,840 Parameters: current_time              = 864000.0
# yt : [INFO     ] 2025-03-17 14:47:54,841 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:47:54,842 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:47:54,842 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:47:54,982 Parameters: current_time              = 866000.0
# yt : [INFO     ] 2025-03-17 14:47:54,983 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:47:54,984 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:47:54,984 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:47:55,150 Parameters: current_time              = 868000.0
# yt : [INFO     ] 2025-03-17 14:47:55,150 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:47:55,150 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:47:55,151 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:47:55,305 Parameters: current_time              = 870000.0
# yt : [INFO     ] 2025-03-17 14:47:55,305 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:47:55,306 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:47:55,307 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:47:55,454 Parameters: current_time              = 872000.0
# yt : [INFO     ] 2025-03-17 14:47:55,454 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:47:55,455 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:47:55,455 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:47:55,823 Parameters: current_time              = 874000.0
# yt : [INFO     ] 2025-03-17 14:47:55,823 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:47:55,824 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:47:55,825 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:47:55,989 Parameters: current_time              = 876000.0
# yt : [INFO     ] 2025-03-17 14:47:55,990 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:47:55,991 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:47:55,992 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:47:56,216 Parameters: current_time              = 878000.0
# yt : [INFO     ] 2025-03-17 14:47:56,217 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:47:56,218 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:47:56,219 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:47:56,413 Parameters: current_time              = 880000.0
# yt : [INFO     ] 2025-03-17 14:47:56,414 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:47:56,415 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:47:56,415 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:47:56,604 Parameters: current_time              = 882000.0
# yt : [INFO     ] 2025-03-17 14:47:56,605 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:47:56,607 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:47:56,608 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:47:56,808 Parameters: current_time              = 884000.0
# yt : [INFO     ] 2025-03-17 14:47:56,809 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:47:56,810 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:47:56,811 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:47:57,010 Parameters: current_time              = 886000.0
# yt : [INFO     ] 2025-03-17 14:47:57,011 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:47:57,013 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:47:57,014 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:47:57,250 Parameters: current_time              = 888000.0
# yt : [INFO     ] 2025-03-17 14:47:57,251 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:47:57,252 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:47:57,252 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:47:57,472 Parameters: current_time              = 890000.0
# yt : [INFO     ] 2025-03-17 14:47:57,473 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:47:57,473 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:47:57,474 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:47:57,705 Parameters: current_time              = 892000.0
# yt : [INFO     ] 2025-03-17 14:47:57,707 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:47:57,708 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:47:57,708 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:47:57,875 Parameters: current_time              = 894000.0
# yt : [INFO     ] 2025-03-17 14:47:57,875 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:47:57,876 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:47:57,877 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:47:58,072 Parameters: current_time              = 896000.0
# yt : [INFO     ] 2025-03-17 14:47:58,073 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:47:58,074 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:47:58,074 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:47:58,243 Parameters: current_time              = 898000.0
# yt : [INFO     ] 2025-03-17 14:47:58,244 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:47:58,245 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:47:58,245 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:47:58,394 Parameters: current_time              = 900000.0
# yt : [INFO     ] 2025-03-17 14:47:58,394 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:47:58,394 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:47:58,395 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-03-17 14:47:58,535 Parameters: current_time              = 900400.0
# yt : [INFO     ] 2025-03-17 14:47:58,536 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2025-03-17 14:47:58,536 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-03-17 14:47:58,537 Parameters: domain_right_edge         = [1. 1. 1.]
